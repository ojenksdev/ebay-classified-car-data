# %% [markdown]
# # Exploring Ebay Car Sale Data
#
# ## Objective
#
# Our goal for this project is clean the data that we intent to work with and analyze it to gain further insight into the used car market Ebay has in Germany.

# %%
import numpy as np
import pandas as pd

# %%
autos = pd.read_csv("autos.csv", encoding="Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head(5)
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# **So Far:**
# It looks like certain columns are missing some data (fuelType, notRepairedDamage, mdoel, gearbox and vehicleType all have less than a count of 50000). The name column should probably be split up by make and model. The odometer column should be a float, we can remove the km and add that to the column name to make better use of the data. Same thing goes for the price column, which is currently a string, but should be a float _(also not sure what currency these prices are in...but seeing as the data is from Germany, I'm guessing Euros.)_

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
old_col = autos.columns

# %%
old_col
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
new_col = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test',
       'vehicle_type', 'registration_year', 'gear_box', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']

old_col = new_col
autos.columns = old_col
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#     gear_box  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# The first change I made to the dataframe had to do with the column names. Some of them were more difficult to understand and needed to be renamed. Also, the original columns used camelcase instead of snake case, so I changed that as well for readability.

# %%
autos.describe(include="all")
# Out:
#                date_crawled         name  seller offer_type  price ab_test  \
# count                 50000        50000   50000      50000  50000   50000
# unique                48213        38754       2          2   2357       2
# top     2016-03-23 18:39:34  Ford_Fiesta  privat    Angebot     $0    test
# freq                      3           78   49999      49999   1421   25756
# mean                    NaN          NaN     NaN        NaN    NaN     NaN
# std                     NaN          NaN     NaN        NaN    NaN     NaN
# min                     NaN          NaN     NaN        NaN    NaN     NaN
# 25%                     NaN          NaN     NaN        NaN    NaN     NaN
# 50%                     NaN          NaN     NaN        NaN    NaN     NaN
# 75%                     NaN          NaN     NaN        NaN    NaN     NaN
# max                     NaN          NaN     NaN        NaN    NaN     NaN
#
# ...

# %% [markdown]
# Looking at the data thus far, it looks like a column we can probably drop is the **nr_of_pictures** as the value is mostly 0.0 across the rows. Another column I'm not too sure about is the **ab_test** column. I don't know how useful that column will be to our research. **unrepaired_damage** might be able to be dropped as well.
#
# We'll need to convert the **price** and **odometer** columns into floats.

# %%
autos["price"].head()
# Out:
# 0    $5,000
# 1    $8,500
# 2    $8,990
# 3    $4,350
# 4    $1,350
# Name: price, dtype: object

# %%
autos["price"] = (autos["price"]
                 .str.replace("$", "")
                 .str.replace(",", "")
                 .astype(float))

# %%
autos["price"].head()
# Out:
# 0    5000.0
# 1    8500.0
# 2    8990.0
# 3    4350.0
# 4    1350.0
# Name: price, dtype: float64

# %% [markdown]
# **Now we can go about converting the odometer column:**

# %%
autos["odometer"].describe()
# Out:
# count         50000
# unique           13
# top       150,000km
# freq          32424
# Name: odometer, dtype: object

# %%
autos["odometer"].head(10)
# Out:
# 0    150,000km
# 1    150,000km
# 2     70,000km
# 3     70,000km
# 4    150,000km
# 5    150,000km
# 6    150,000km
# 7    150,000km
# 8    150,000km
# 9    150,000km
# Name: odometer, dtype: object

# %% [markdown]
# **_We can see there is a str 'km' and a comma that need to be removed before we can convert:_**

# %%
autos["odometer"] = (autos["odometer"]
                    .str.replace(",", "")
                    .str.replace("km", ""))
autos["odometer"].head()
# Out:
# 0    150000
# 1    150000
# 2     70000
# 3     70000
# 4    150000
# Name: odometer, dtype: object

# %% [markdown]
# **_Now we can convert the strings over to type float:_**

# %%
autos["odometer"] = autos["odometer"].astype(float)

# %%
autos["odometer"].head()
# Out:
# 0    150000.0
# 1    150000.0
# 2     70000.0
# 3     70000.0
# 4    150000.0
# Name: odometer, dtype: float64

# %% [markdown]
# **_There we go! Converted over to floats. Next thing we need to do is rename the column since we removed the km from data:_**

# %%
autos.rename({"odometer":"odometer_km"}, axis=1, inplace=True)

# %% [markdown]
# **_Odometer is taken care of now! Lets move on._**

# %%
autos["odometer_km"].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %% [markdown]
# I think the odometer readings are pretty good, especially for used cars. I don't see any range or amount of miles that is out of the ordinary, so I will move on to the price column.

# %%
autos["price"].value_counts().sort_index(ascending=True)
# Out:
# 0.0           1421
# 1.0            156
# 2.0              3
# 3.0              1
# 5.0              2
# 8.0              1
# 9.0              1
# 10.0             7
# 11.0             2
# 12.0             3
# 13.0             2
# 14.0             1
# 15.0             2
# 17.0             3
# 18.0             1
# 20.0             4
# 25.0             5
# 29.0             1
# 30.0             7
# 35.0             1
# 40.0             6
# 45.0             4
# 47.0             1
# 49.0             4
# 50.0            49
# 55.0             2
# 59.0             1
# 60.0             9
# 65.0             5
# 66.0             1
#               ...
# 151990.0         1
# 155000.0         1
# 163500.0         1
# 163991.0         1
# 169000.0         1
# 169999.0         1
# 175000.0         1
# 180000.0         1
# 190000.0         1
# 194000.0         1
# 197000.0         1
# 198000.0         1
# 220000.0         1
# 250000.0         1
# 259000.0         1
# 265000.0         1
# ...

# %% [markdown]
# **Ok, while it is 'possible' to be selling a used car for over 100k, I'm not sure if we'd find those in ebay classifieds. Time to look a bit deeper into the data to examine what kind of cars these are.**
#
# **The same goes for the cars that are 'free'**

# %%
free_cars = autos[autos["price"] == 0.0]
free_cars.head()
# Out:
#            date_crawled                                               name  \
# 27  2016-03-27 18:45:01             Hat_einer_Ahnung_mit_Ford_Galaxy_HILFE
# 71  2016-03-28 19:39:35  Suche_Opel_Astra_F__Corsa_oder_Kadett_E_mit_Re...
# 80  2016-03-09 15:57:57  Nissan_Primera_Hatchback_1_6_16v_73_Kw___99Ps_...
# 87  2016-03-29 23:37:22                      Bmw_520_e39_zum_ausschlachten
# 99  2016-04-05 09:48:54                    Peugeot_207_CC___Cabrio_Bj_2011
#
#     seller offer_type  price  ab_test vehicle_type  registration_year  \
# 27  privat    Angebot    0.0  control          NaN               2005
# 71  privat    Angebot    0.0  control          NaN               1990
# 80  privat    Angebot    0.0  control        coupe               1999
# 87  privat    Angebot    0.0  control          NaN               2000
# 99  privat    Angebot    0.0  control       cabrio               2011
#
#    gear_box  power_ps    model  odometer_km  registration_month fuel_type  \
# ...

# %% [markdown]
# As I thought, these "free" vehicles aren't needed in our data because we have no way of truly knowing why they are labeled free. My guess is the person who added them to the classifieds either forgot to add the price (which is rare, but I guess possible), or they are trying to lure in potential buyers in an odd fashion. Either way, this data will be removed.

# %%
autos = autos[autos["price"] > 0.0]
autos["price"].value_counts().sort_index(ascending=True)
# Out:
# 1.0           156
# 2.0             3
# 3.0             1
# 5.0             2
# 8.0             1
# 9.0             1
# 10.0            7
# 11.0            2
# 12.0            3
# 13.0            2
# 14.0            1
# 15.0            2
# 17.0            3
# 18.0            1
# 20.0            4
# 25.0            5
# 29.0            1
# 30.0            7
# 35.0            1
# 40.0            6
# 45.0            4
# 47.0            1
# 49.0            4
# 50.0           49
# 55.0            2
# 59.0            1
# 60.0            9
# 65.0            5
# 66.0            1
# 70.0           10
#              ...
# 151990.0        1
# 155000.0        1
# 163500.0        1
# 163991.0        1
# 169000.0        1
# 169999.0        1
# 175000.0        1
# 180000.0        1
# 190000.0        1
# 194000.0        1
# 197000.0        1
# 198000.0        1
# 220000.0        1
# 250000.0        1
# 259000.0        1
# 265000.0        1
# 295000.0        1
# 299000.0        1
# 345000.0        1
# ...

# %% [markdown]
# **Ok, we've removed all of the free vehicles from the data. Now, lets take out the car listings with a price over 350k as the next price after that is just shy of a million dollars:**

# %%
pricey_cars = autos[autos["price"] > 350001]
pricey_cars.head(5)
# Out:
#               date_crawled                                               name  \
# 514    2016-03-17 09:53:08                   Ford_Focus_Turnier_1.6_16V_Style
# 2897   2016-03-12 21:50:57   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000
# 7814   2016-04-04 11:53:31                                        Ferrari_F40
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# 22947  2016-03-22 12:54:19                         Bmw_530d_zum_ausschlachten
#
#        seller offer_type       price  ab_test vehicle_type  registration_year  \
# 514    privat    Angebot    999999.0     test        kombi               2009
# 2897   privat    Angebot  11111111.0     test    limousine               1973
# 7814   privat    Angebot   1300000.0  control        coupe               1992
# 11137  privat    Angebot  10000000.0  control        coupe               1960
# 22947  privat    Angebot   1234566.0  control        kombi               1999
#
# ...

# %% [markdown]
# **Now this is something I wasn't expecting to see. It does appear some people are selling cars that are luxury and collectors items for extremely high prices. However, because the amount of cars is so low, we'll still remove them**

# %%
autos = autos[autos["price"] < 350001]

# %%
autos["price"].value_counts().sort_index(ascending=True)
# Out:
# 1.0         156
# 2.0           3
# 3.0           1
# 5.0           2
# 8.0           1
# 9.0           1
# 10.0          7
# 11.0          2
# 12.0          3
# 13.0          2
# 14.0          1
# 15.0          2
# 17.0          3
# 18.0          1
# 20.0          4
# 25.0          5
# 29.0          1
# 30.0          7
# 35.0          1
# 40.0          6
# 45.0          4
# 47.0          1
# 49.0          4
# 50.0         49
# 55.0          2
# 59.0          1
# 60.0          9
# 65.0          5
# 66.0          1
# 70.0         10
#            ...
# 119500.0      1
# 119900.0      1
# 120000.0      2
# 128000.0      1
# 129000.0      1
# 130000.0      1
# 135000.0      1
# 137999.0      1
# 139997.0      1
# 145000.0      1
# 151990.0      1
# 155000.0      1
# 163500.0      1
# 163991.0      1
# 169000.0      1
# 169999.0      1
# 175000.0      1
# 180000.0      1
# 190000.0      1
# 194000.0      1
# 197000.0      1
# 198000.0      1
# 220000.0      1
# 250000.0      1
# ...

# %% [markdown]
# **From here we can see the cleaned column for price. We still have those outliers that are above 100k, but we will keep those in as they are specialty vehicles.**

# %% [markdown]
# **Now, lets take a look at the date columns and clean them as needed:**

# %%
autos["date_crawled"].value_counts(normalize=True, dropna=False).sort_index(ascending=False)
# Out:
# 2016-04-07 14:36:56    0.000021
# 2016-04-07 14:36:55    0.000021
# 2016-04-07 14:36:44    0.000021
# 2016-04-07 14:30:26    0.000021
# 2016-04-07 14:30:09    0.000021
# 2016-04-07 14:07:04    0.000021
# 2016-04-07 13:36:38    0.000021
# 2016-04-07 13:36:37    0.000021
# 2016-04-07 13:36:20    0.000021
# 2016-04-07 13:36:19    0.000021
# 2016-04-07 13:25:39    0.000021
# 2016-04-07 13:06:18    0.000021
# 2016-04-07 12:25:35    0.000021
# 2016-04-07 12:25:34    0.000021
# 2016-04-07 12:06:23    0.000021
# 2016-04-07 12:06:19    0.000021
# 2016-04-07 11:36:35    0.000021
# 2016-04-07 11:36:34    0.000041
# 2016-04-07 11:36:25    0.000021
# 2016-04-07 11:36:24    0.000021
# 2016-04-07 11:36:23    0.000021
# 2016-04-07 11:36:19    0.000021
# 2016-04-07 11:06:33    0.000021
# 2016-04-07 10:36:37    0.000041
# 2016-04-07 10:36:36    0.000021
# 2016-04-07 10:36:35    0.000021
# 2016-04-07 10:36:25    0.000021
# 2016-04-07 10:36:24    0.000021
# 2016-04-07 10:36:19    0.000021
# ...

# %%
autos["date_crawled"].describe()
# Out:
# count                   48565
# unique                  46882
# top       2016-03-19 17:36:18
# freq                        3
# Name: date_crawled, dtype: object

# %% [markdown]
# The **date_crawled** column shows us when data was scraped from the original site. Nearly all of the entries are unique, because of the timestamp. It might make sense to simply remove this in order to find patterns along the days.

# %%
autos["ad_created"].describe()
# Out:
# count                   48565
# unique                     76
# top       2016-04-03 00:00:00
# freq                     1887
# Name: ad_created, dtype: object

# %% [markdown]
# Now if we take a look at the **ad_created** column, we can see that the number of unique entries is much smaller. This is likely because the timestamp is set to all zeros for a majority of the rows.

# %%
autos["last_seen"].describe()
# Out:
# count                   48565
# unique                  38474
# top       2016-04-07 06:17:27
# freq                        8
# Name: last_seen, dtype: object

# %% [markdown]
# The **last_seen** column has a similar structrue to the **date_crawled** one. More unique entries due to the fact the timestamps are unique. We would want to remove the timestamp in order to find patterns in the data based on the date only.

# %%
autos["registration_year"].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %%
autos["registration_year"].value_counts().sort_index(ascending=False)
# Out:
# 9999       3
# 9000       1
# 8888       1
# 6200       1
# 5911       1
# 5000       4
# 4800       1
# 4500       1
# 4100       1
# 2800       1
# 2019       2
# 2018     470
# 2017    1392
# 2016    1220
# 2015     392
# 2014     663
# 2013     803
# 2012    1310
# 2011    1623
# 2010    1589
# 2009    2085
# 2008    2215
# 2007    2277
# 2006    2670
# 2005    2936
# 2004    2703
# 2003    2699
# 2002    2486
# 2001    2636
# 2000    3156
#         ...
# 1964      12
# 1963       8
# 1962       4
# 1961       6
# 1960      23
# 1959       6
# 1958       4
# 1957       2
# 1956       4
# 1955       2
# 1954       2
# 1953       1
# 1952       1
# 1951       2
# 1950       3
# 1948       1
# 1943       1
# 1941       2
# 1939       1
# 1938       1
# 1937       4
# 1934       2
# 1931       1
# 1929       1
# 1927       1
# 1910       5
# 1800       2
# 1111       1
# 1001       1
# 1000       1
# Name: registration_year, Length: 95, dtype: int64

# %% [markdown]
# **We can see by looking at the registration_year column that there are clearly some years that we need to remove from the column. Anything under 1910 can go and the same goes for anything over 2019.**

# %%
old_classics = autos[autos["registration_year"] == 1910]
old_classics
# Out:
#               date_crawled                              name  seller  \
# 3679   2016-04-04 00:36:17                        Suche_Auto  privat
# 22659  2016-03-14 08:51:18                      Opel_Corsa_B  privat
# 28693  2016-03-22 17:48:41                    Renault_Twingo  privat
# 30781  2016-03-25 13:47:46  Opel_Calibra_V6_DTM_Bausatz_1:24  privat
# 45157  2016-03-11 22:37:01                        Motorhaube  privat
#
#       offer_type  price  ab_test vehicle_type  registration_year gear_box  \
# 3679     Angebot    1.0     test          NaN               1910      NaN
# 22659    Angebot  500.0     test          NaN               1910      NaN
# 28693    Angebot  599.0  control   kleinwagen               1910  manuell
# 30781    Angebot   30.0     test          NaN               1910      NaN
# 45157    Angebot   15.0  control          NaN               1910      NaN
#
#        power_ps    model  odometer_km  registration_month fuel_type  \
# ...

# %% [markdown]
# We can see these cars from 1910 are older vehicles, so they probably fall under the category of collectors items. We will remove anything older than 1910 from our list.

# %%
autos[autos["registration_year"] > 2015].sort_index(ascending=True)
# Out:
#               date_crawled                                               name  \
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# 55     2016-03-07 02:47:54                     Mercedes_E320_AMG_zu_Tauschen!
# 59     2016-03-17 17:50:54               Mercedes_A_Klasse_W_168__A_140_gruen
# 65     2016-04-04 19:30:39                      Ford_Fiesta_zum_ausschlachten
# 68     2016-04-03 17:36:59  Mini_cooper_s_clubman_/vollausstattung_/_Navi/...
# 76     2016-03-22 14:52:57                         BMW_318i_neustes_Model_0Km
# 84     2016-03-27 19:52:54                                     Renault_twingo
# 101    2016-03-22 17:51:49    Schnaepchen_in_einem_Jahr_OLDTEIMER_KENNZEICHEN
# 113    2016-04-03 14:58:29                              Golf_4_Anfaenger_auto
# 135    2016-03-12 11:00:10  Opel_Meriva_B_Panoramadach__Sitz__und_Lenkradh...
# 164    2016-03-13 20:39:16  Opel_Meriva__nur_76000_Km__unfallfrei__scheckh...
# ...

# %% [markdown]
# Taking a look at the registration_year and the last_seen columns, it's clear that anything over 2016 is inaccurate, and likely has to be removed. These vehicles were added in 2016, so the first registration year cannot be in the future:

# %%
autos = autos[autos["registration_year"] > 1909]

# %%
autos["registration_year"].value_counts().sort_index(ascending=False)
# Out:
# 9999       3
# 9000       1
# 8888       1
# 6200       1
# 5911       1
# 5000       4
# 4800       1
# 4500       1
# 4100       1
# 2800       1
# 2019       2
# 2018     470
# 2017    1392
# 2016    1220
# 2015     392
# 2014     663
# 2013     803
# 2012    1310
# 2011    1623
# 2010    1589
# 2009    2085
# 2008    2215
# 2007    2277
# 2006    2670
# 2005    2936
# 2004    2703
# 2003    2699
# 2002    2486
# 2001    2636
# 2000    3156
#         ...
# 1968      26
# 1967      26
# 1966      22
# 1965      17
# 1964      12
# 1963       8
# 1962       4
# 1961       6
# 1960      23
# 1959       6
# 1958       4
# 1957       2
# 1956       4
# 1955       2
# 1954       2
# 1953       1
# 1952       1
# 1951       2
# 1950       3
# 1948       1
# 1943       1
# 1941       2
# 1939       1
# 1938       1
# 1937       4
# 1934       2
# 1931       1
# 1929       1
# 1927       1
# 1910       5
# Name: registration_year, Length: 91, dtype: int64

# %%
autos = autos[autos["registration_year"] < 2017]

# %%
autos["registration_year"].value_counts(normalize=True).sort_index(ascending=False)
# Out:
# 2016    0.026135
# 2015    0.008397
# 2014    0.014203
# 2013    0.017202
# 2012    0.028063
# 2011    0.034768
# 2010    0.034040
# 2009    0.044665
# 2008    0.047450
# 2007    0.048778
# 2006    0.057197
# 2005    0.062895
# 2004    0.057904
# 2003    0.057818
# 2002    0.053255
# 2001    0.056468
# 2000    0.067608
# 1999    0.062060
# 1998    0.050620
# 1997    0.041794
# 1996    0.029412
# 1995    0.026285
# 1994    0.013474
# 1993    0.009104
# 1992    0.007926
# 1991    0.007262
# 1990    0.007433
# 1989    0.003727
# 1988    0.002892
# 1987    0.001542
#           ...
# 1968    0.000557
# 1967    0.000557
# 1966    0.000471
# 1965    0.000364
# 1964    0.000257
# 1963    0.000171
# 1962    0.000086
# 1961    0.000129
# 1960    0.000493
# 1959    0.000129
# 1958    0.000086
# 1957    0.000043
# 1956    0.000086
# 1955    0.000043
# 1954    0.000043
# 1953    0.000021
# 1952    0.000021
# 1951    0.000043
# 1950    0.000064
# 1948    0.000021
# 1943    0.000021
# ...

# %%
autos["registration_year"].describe()
# Out:
# count    46681.000000
# mean      2002.910756
# std          7.185103
# min       1910.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2016.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# It looks like most of the cars listed were registered around the year 2000. Quite a few vehicles were listed as being registered in 2016, but I wonder if that is simply based around the date last_seen online. I noticed that the registration_month is 0 for quite a few entries.

# %%
autos["brand"].value_counts().sort_index(ascending=False)
# Out:
# volvo              427
# volkswagen        9862
# trabant             65
# toyota             593
# suzuki             277
# subaru             100
# sonstige_autos     458
# smart              661
# skoda              766
# seat               853
# saab                77
# rover               62
# renault           2201
# porsche            286
# peugeot           1393
# opel              5022
# nissan             713
# mitsubishi         384
# mini               409
# mercedes_benz     4503
# mazda              709
# land_rover          98
# lancia              50
# lada                27
# kia                330
# jeep               106
# jaguar              73
# hyundai            468
# honda              366
# ford              3263
# fiat              1197
# daihatsu           117
# daewoo              70
# dacia              123
# citroen            654
# chrysler           164
# chevrolet          266
# bmw               5137
# audi              4041
# alfa_romeo         310
# ...

# %% [markdown]
# What I want to take a look at is the 5 most popular vehicles to see if there is any pattern linking their popularity. **Volkswagon** is clearly the most popular used car for sale. Next up is **bmw** and then **opel**. We close out the list with **mercedez_benz** and **audi**.

# %%
most_pop_on_sale = {}
popular_cars = ["volkswagen", "bmw", "opel", "mercedes_benz", "audi"]

for c in popular_cars:
    car = autos[autos["brand"] == c]
    mean = car["price"].mean()
    most_pop_on_sale[c] = mean

print(most_pop_on_sale)
# Out:
# {'bmw': 8332.820517811953, 'audi': 9336.687453600594, 'mercedes_benz': 8628.450366422385, 'opel': 2975.2419354838707, 'volkswagen': 5402.410261610221}

# %% [markdown]
# After running the loop on the selected vehicles, it appears that the most popular cars have an average price under 10,000 dollars. This might be the reason for the popularity.
#
# Another thing I wonder is if sellers are going for a lower price than what the vehicles are actually worth. What makes the Audi vehicles worth more than the Mercedes-Benz? And are the Volkswagen vehicles priced to sell due to other reasons? We would need more data to find out.

# %%
pop_car_mileage = {}

for c in popular_cars:
    car = autos[autos["brand"] == c]
    mean = car["odometer_km"].mean()
    pop_car_mileage[c] = mean
 
pop_car_mileage
# Out:
# {'audi': 129157.38678544914,
#  'bmw': 132572.51313996495,
#  'mercedes_benz': 130788.36331334666,
#  'opel': 129310.0358422939,
#  'volkswagen': 128707.15879132022}

# %% [markdown]
# Now lets convert these two dictionaries into objects:

# %%
pop_prices_series = pd.Series(most_pop_on_sale)
print(pop_prices_series)
# Out:
# audi             9336.687454
# bmw              8332.820518
# mercedes_benz    8628.450366
# opel             2975.241935
# volkswagen       5402.410262
# dtype: float64

# %%
pop_cars = pd.DataFrame(pop_prices_series, columns=["mean_prices"])
pop_cars
# Out:
#                mean_prices
# audi           9336.687454
# bmw            8332.820518
# mercedes_benz  8628.450366
# opel           2975.241935
# volkswagen     5402.410262

# %%
pop_mileage_series = pd.Series(pop_car_mileage)
pop_cars["mean_mileage"] = pop_mileage_series
pop_cars
# Out:
#                mean_prices   mean_mileage
# audi           9336.687454  129157.386785
# bmw            8332.820518  132572.513140
# mercedes_benz  8628.450366  130788.363313
# opel           2975.241935  129310.035842
# volkswagen     5402.410262  128707.158791

# %% [markdown]
# ### Findings:
# Looking at this dataframe for the most popular cars, its clear the mileage isn't necessarily playing a factor in the cost of the vehicle. **bmw** appears to have an average mileage of 132k _(highest in the bunch)_, but comes in at the second highest average cost _($8,332)_.
#
# Looking at this df, the **volkswagen** and **opel** seem to be the best value, price and mileage-wise. However, it would be nice to have seen some data regarding the # of accidents, recalls, avg cost of repairs, for each brand to get a true sense of the value for a buyer.
